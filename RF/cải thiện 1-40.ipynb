# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from vnstock import *
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import yfinance as yf
import os
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
data_ticker = pd.read_excel("C:\\Users\\Chi Bao\\OneDrive\\Desktop\\Đồ án tốt nghiệp\\data_ticker.xlsx")

FI = ['GC=F','SI=F','CL=F','^GSPC','^DJI','^IXIC','^RUT','^FTSE','^N225','^NYA']
df = pd.DataFrame()
for symbol in FI:
    data = yf.download(symbol, start='2012-03-20', end='2023-09-06')
    df[symbol] = data['Adj Close']

column_mapping = {
    'GC=F': 'Gold',
    'SI=F': 'Silver',
    'CL=F': 'Crude Oil',
    '^GSPC': 'S&P 500',
    '^DJI': 'Dow Jones',
    '^IXIC': 'NASDAQ',
    '^RUT': 'Russell 2000',
    '^FTSE': 'FTSE 100',
    '^N225': 'Nikkei 225',
    '^NYA': 'NYSE'
}

df = df.rename(columns=column_mapping)
df.dropna()

returns_df = df.pct_change()*100
returns_df.columns = [col + '_return' for col in returns_df.columns]
returns_df = returns_df.dropna()

###

FI = ['VNINDEX','HNX','VN30','HNX30','UPCOM']
data = stock_historical_data('VNINDEX', '2012-03-19', '2023-09-05', "1D", "index")
d_new = data.set_index('time')
d_new['VNINDEX'] = data['close']
df1 = pd.DataFrame()
for symbol in FI:
    data = stock_historical_data(symbol, '2012-03-19', '2023-09-05', "1D", "index")
    data = data.set_index('time')
    df1[symbol] = data['close']
df1 = df1.dropna()

returns_df1 = df1.pct_change()*100
returns_df1.columns = [col + '_return' for col in returns_df1.columns]
returns_df1 = returns_df1.dropna()
returns_df1.head(42069)

###

lagreturn = pd.DataFrame()

for column in returns_df.columns:
    lagreturn[f'{column}_Lag1'] = returns_df[column].shift(1)
for column in returns_df.columns:
    lagreturn[f'{column}_Lag2'] = returns_df[column].shift(2)
lagreturn = lagreturn.dropna()

lagreturn1 = pd.DataFrame()
for column in returns_df1.columns:
    lagreturn1[f'{column}_Lag1'] = returns_df1[column].shift(1)
for column in returns_df1.columns:
    lagreturn1[f'{column}_Lag2'] = returns_df1[column].shift(2)
lagreturn1 = lagreturn1.dropna()
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
def do_tre_vnstock(symbol, start_date, end_date, lags=10): 
    ts = stock_historical_data(symbol,start_date, end_date)
    ts = ts.dropna(subset=['close'])


    tsret = pd.DataFrame(index=ts.index)
    tsret['time']=ts['time']
    tsret["Today"] = ts["close"].pct_change()*100

    for i,x in enumerate(tsret["Today"]):
        if (abs(x) < 0.0001):
            tsret["Today"][i] = 0.0001

    for i in range(0, lags):
        tsret["Lag%s" % str(i+1)] = tsret["Today"].shift(i+1)

    tsret["Direction"] = np.sign(tsret["Today"])
    tsret = tsret.dropna()
    tsret = tsret.set_index('time')
    bpt = pd.merge(tsret, lagreturn, left_index=True, right_index=True)
    bpt1 = pd.merge(bpt, lagreturn1, left_index=True, right_index=True)
    bpt1.fillna(0, inplace=True)
    bpt1 = bpt1[(bpt1 != 0).all(axis=1)]
    return bpt1

# %%
file_path = r"C:\Users\Chi Bao\OneDrive\Desktop\Đồ án tốt nghiệp\Code\RF\Danh sách ticker\1-40.xlsx"
result_file_path = r"C:\Users\Chi Bao\OneDrive\Desktop\Đồ án tốt nghiệp\Code\RF\Kết quả cải thiện\1-40.xlsx"

# %%
#MODEL
list_i = []
list_return_price = []
list_k, list_t = [], []
list_rmse, list_mse, list_mae = [], [], []
list_r2_train = []
list_r2_test = []

original_data = pd.read_excel(file_path)

if os.path.exists(result_file_path):
    result_df = pd.read_excel(result_file_path)
else:
    result_df = pd.DataFrame(columns=['Stock', 'Predict', 'R2_train', 'R2_test', 'RMSE', 'MSE', 'MAE', 'test size', 'trees'])

    
try:     
    for i in original_data['ticker']:
        try:
            data = do_tre_vnstock(i, '2012-03-19', '2023-09-05', lags=10)

            X = data.loc[:, ~data.columns.isin(['Today'])]
            y = data["Today"]

            list_k1, list_t1 = [], []
            list_score = []
            for k in np.arange(0.1, 0.5, 0.01):
                for t in range(30,51):
                    model = RandomForestRegressor(n_estimators=t, random_state=12)
                    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=k, random_state=12, shuffle=False)
                    model.fit(X_train, y_train)
                    yhat_test = model.predict(X_test)
                    score = model.score(X_test, y_test)
                    list_k1.append(k)
                    list_t1.append(t)
                    list_score.append(score)

            score_max = max(list_score)  
            a = list_score.index(score_max)
            k = list_k1[a]
            t = list_t1[a]
    
            model = RandomForestRegressor(n_estimators=t, random_state=12)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=k, random_state=12, shuffle=False)
            model.fit(X_train, y_train)
            yhat_test = model.predict(X_test)
            r2_train = model.score(X_train, y_train)
            r2_test = model.score(X_test, y_test)
            rmse = mean_squared_error(y_test, yhat_test, squared=False)
            mse = mean_squared_error(y_test, yhat_test, squared=True)
            mae = mean_absolute_error(y_test, yhat_test)

            X_predict = [X.iloc[-1].values.tolist()]
            Y_predict = model.predict(X_predict)

            list_i.append(i)
            list_k.append(k)
            list_t.append(t)
            list_return_price.append(Y_predict)
            list_r2_train.append(r2_train)
            list_r2_test.append(r2_test)
            list_rmse.append(rmse)
            list_mse.append(mse)
            list_mae.append(mae)

            print('Stock:',i,f' Predict: {Y_predict.item():.2f}',f' R2_train: {r2_train:.2f}',f' R2_test: {r2_test:.2f}',
                f' RMSE: {rmse:.2f}', f' MSE: {mse:.2f}', f' MAE: {mae:.2f}', f'test size: {k:.2f}', 'trees', t)
            
            result_df = pd.concat([result_df, pd.DataFrame({
                'Stock': [i],
                'Predict': [Y_predict.item()],
                'R2_train': [r2_train],
                'R2_test': [r2_test],
                'RMSE': [rmse],
                'MSE': [mse],
                'MAE': [mae],
                'test size': [k],
                'trees': [t]
            })], ignore_index=True)

            original_data = original_data[original_data['ticker'] != i]
            result_df.to_excel(result_file_path, index=False)
            
        except Exception as e:
            print(f"Stock: {i} -Unpredictable!\n" f'{e}')
            result_df.to_excel(result_file_path, index=False)
            original_data.to_excel(file_path, index=False)
            continue

except KeyboardInterrupt:
    print("Dừng vòng for. Kết quả lưu trong file:", result_file_path)
    result_df.to_excel(result_file_path, index=False)
    original_data.to_excel(file_path, index=False)

print("Đang tạm dừng!")
# Out:
# Stock: SSI  Predict: -1.43  R2_train: 0.93  R2_test: 0.64  RMSE: 1.80  MSE: 3.24  MAE: 1.44 test size: 0.40 trees 31
# Stock: BCM  Predict: -1.06  R2_train: 0.91  R2_test: 0.48  RMSE: 1.51  MSE: 2.29  MAE: 1.04 test size: 0.48 trees 30
# Stock: VHM  Predict: 1.17  R2_train: 0.92  R2_test: 0.52  RMSE: 1.58  MSE: 2.50  MAE: 1.16 test size: 0.23 trees 50
# Stock: VIC  Predict: 0.70  R2_train: 0.90  R2_test: 0.49  RMSE: 1.71  MSE: 2.92  MAE: 1.17 test size: 0.30 trees 42
# Stock: VRE  Predict: -1.01  R2_train: 0.93  R2_test: 0.58  RMSE: 1.17  MSE: 1.36  MAE: 0.88 test size: 0.20 trees 47
# Stock: BVH  Predict: 1.57  R2_train: 0.93  R2_test: 0.53  RMSE: 1.32  MSE: 1.75  MAE: 1.02 test size: 0.41 trees 45
# Stock: POW  Predict: 1.66  R2_train: 0.93  R2_test: 0.58  RMSE: 1.51  MSE: 2.28  MAE: 1.19 test size: 0.41 trees 45
# Stock: GAS  Predict: 0.84  R2_train: 0.93  R2_test: 0.59  RMSE: 0.70  MSE: 0.49  MAE: 0.57 test size: 0.13 trees 41
# Stock: ACB  Predict: 0.63  R2_train: 0.91  R2_test: 0.57  RMSE: 1.21  MSE: 1.46  MAE: 0.88 test size: 0.41 trees 32
# Stock: BID  Predict: 0.78  R2_train: 0.92  R2_test: 0.55  RMSE: 1.47  MSE: 2.16  MAE: 1.12 test size: 0.29 trees 30
# Stock: CTG  Predict: 1.33  R2_train: 0.92  R2_test: 0.56  RMSE: 1.48  MSE: 2.19  MAE: 1.08 test size: 0.39 trees 45
# Stock: HDB  Predict: 0.80  R2_train: 0.93  R2_test: 0.58  RMSE: 1.09  MSE: 1.19  MAE: 0.90 test size: 0.24 trees 43
# Stock: MBB  Predict: 0.80  R2_train: 0.92  R2_test: 0.56  RMSE: 1.27  MSE: 1.62  MAE: 0.97 test size: 0.26 trees 42
# Stock: SSB  Predict: -1.18  R2_train: 0.89  R2_test: 0.31  RMSE: 1.11  MSE: 1.23  MAE: 0.63 test size: 0.24 trees 43
# Stock: SHB  Predict: 1.05  R2_train: 0.92  R2_test: 0.52  RMSE: 1.70  MSE: 2.90  MAE: 1.28 test size: 0.32 trees 50
# Stock: STB  Predict: 1.03  R2_train: 0.94  R2_test: 0.64  RMSE: 1.69  MSE: 2.87  MAE: 1.27 test size: 0.30 trees 50
# Stock: TCB  Predict: 1.46  R2_train: 0.92  R2_test: 0.56  RMSE: 1.56  MSE: 2.44  MAE: 1.11 test size: 0.36 trees 32
# Stock: TPB  Predict: 1.49  R2_train: 0.92  R2_test: 0.54  RMSE: 0.92  MSE: 0.86  MAE: 0.75 test size: 0.11 trees 35
# Stock: VCB  Predict: 0.94  R2_train: 0.92  R2_test: 0.55  RMSE: 0.98  MSE: 0.96  MAE: 0.76 test size: 0.22 trees 37
# Stock: VIB  Predict: 0.99  R2_train: 0.93  R2_test: 0.52  RMSE: 1.59  MSE: 2.52  MAE: 1.16 test size: 0.40 trees 50
# Stock: VPB  Predict: 1.08  R2_train: 0.92  R2_test: 0.56  RMSE: 0.95  MSE: 0.91  MAE: 0.70 test size: 0.14 trees 40
# Stock: HPG  Predict: 1.49  R2_train: 0.93  R2_test: 0.61  RMSE: 1.64  MSE: 2.68  MAE: 1.21 test size: 0.46 trees 33
# Stock: GVR  Predict: 2.15  R2_train: 0.93  R2_test: 0.61  RMSE: 1.88  MSE: 3.54  MAE: 1.49 test size: 0.34 trees 37
# Stock: MSN  Predict: 1.70  R2_train: 0.93  R2_test: 0.59  RMSE: 1.61  MSE: 2.60  MAE: 1.24 test size: 0.49 trees 48
# Stock: VNM  Predict: 0.44  R2_train: 0.92  R2_test: 0.56  RMSE: 0.81  MSE: 0.66  MAE: 0.61 test size: 0.25 trees 38
# Stock: SAB  Predict: 1.04  R2_train: 0.92  R2_test: 0.58  RMSE: 0.88  MSE: 0.78  MAE: 0.71 test size: 0.27 trees 41
# Stock: VJC  Predict: 0.71  R2_train: 0.92  R2_test: 0.59  RMSE: 0.67  MSE: 0.45  MAE: 0.44 test size: 0.12 trees 40
# Stock: MWG  Predict: 1.25  R2_train: 0.91  R2_test: 0.55  RMSE: 1.70  MSE: 2.90  MAE: 1.25 test size: 0.29 trees 42
# Stock: PLX  Predict: 0.89  R2_train: 0.92  R2_test: 0.56  RMSE: 1.39  MSE: 1.94  MAE: 1.06 test size: 0.47 trees 35
# Stock: FPT  Predict: 1.03  R2_train: 0.91  R2_test: 0.47  RMSE: 1.30  MSE: 1.69  MAE: 0.93 test size: 0.44 trees 42
# Stock: AGR  Predict: 1.47  R2_train: 0.93  R2_test: 0.57  RMSE: 1.97  MSE: 3.90  MAE: 1.56 test size: 0.30 trees 31
# Stock: APG  Predict: -2.71  R2_train: 0.95  R2_test: 0.65  RMSE: 1.98  MSE: 3.92  MAE: 1.51 test size: 0.28 trees 32
# Stock: BCG  Predict: -1.40  R2_train: 0.94  R2_test: 0.66  RMSE: 2.05  MSE: 4.19  MAE: 1.64 test size: 0.35 trees 31
# Stock: BSI  Predict: 1.59  R2_train: 0.93  R2_test: 0.63  RMSE: 2.16  MSE: 4.67  MAE: 1.71 test size: 0.40 trees 47
# Stock: CTS  Predict: 3.15  R2_train: 0.93  R2_test: 0.63  RMSE: 2.27  MSE: 5.16  MAE: 1.88 test size: 0.45 trees 31
# Stock: EVF  Predict: 1.47  R2_train: 0.91  R2_test: 0.58  RMSE: 1.70  MSE: 2.88  MAE: 1.17 test size: 0.10 trees 35
# Stock: FIT  Predict: 2.09  R2_train: 0.93  R2_test: 0.62  RMSE: 1.86  MSE: 3.44  MAE: 1.44 test size: 0.11 trees 38
# Stock: FTS  Predict: 2.42  R2_train: 0.93  R2_test: 0.66  RMSE: 2.06  MSE: 4.25  MAE: 1.71 test size: 0.36 trees 30
# Stock: HCM  Predict: 1.79  R2_train: 0.93  R2_test: 0.64  RMSE: 2.05  MSE: 4.22  MAE: 1.60 test size: 0.44 trees 33
# Stock: IBC  Predict: 1.03  R2_train: 0.91  R2_test: 0.66  RMSE: 2.39  MSE: 5.73  MAE: 1.79 test size: 0.24 trees 34
# Đang tạm dừng!
